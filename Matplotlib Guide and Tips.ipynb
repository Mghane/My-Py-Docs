# %%
conda install matplotlib
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# This code makes us able to see matplotlib plot in jupyter notebook

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)

# %%
y=x**2

# %% [markdown]
# * ### Method 1- Functional Method###

# %%
plt.plot(x,y,"r*")
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('My Title')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# * ### Method 2- Object Oriented###
# ** Create figure object and apply methods on that**

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.95,0.9])
axes1.set_xlabel("big x")
axes1.set_ylabel("big y")
axes1.set_title("big title")
axes1.plot(x,y,'r')

axes2=fig.add_axes([0.2,0.6,0.4,0.3])
axes2.set_xlabel("small x")
axes2.set_ylabel("small y")
axes2.set_title("small title")
axes2.plot(y,x,'*')
plt.show()

# %% [markdown]
# *Creating Subplot using object oriented method in matplotlib*

# %%
#fig=plt.figure()
#axes=fig.subplots(nrows=1, ncols=2)  
fig,axes=plt.subplots(nrows=1, ncols=2) # it does add_axes automatically based on nrows and ncols
plt.tight_layout(3) # to make some gaps between tight plots
axes[0].plot(x,y)
axes[0].set_xlabel('0 x')
axes[0].set_ylabel('0 y')
axes[0].set_title('firsr plot')

axes[1].plot(x,y)
axes[1].set_xlabel('1 x')
axes[1].set_ylabel('1 y')
axes[1].set_title('second plot')
# Out:
# Text(0.5, 1, 'second plot')

# %% [markdown]
# #### Figure Size and DPI###

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(8,3),dpi=100)
axes[0].plot(x,y)
axes[1].plot(y,x, 'r .')
plt.tight_layout()

# %% [markdown]
# **Save the picture**

# %%
fig.savefig('my_picture.png', dpi=200)

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.5])
ax.plot(x,y, label='x and y')
ax.plot(y,x, label='y and x')
ax.legend(loc=0)  # check the help to see all options for legend location
# legend location can be tuple (0.1,0.2) as to specifiy the location of bottom left corner of the legend
plt.show()

# %% [markdown]
# **Modify Appearance**

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,'purple', linewidth=2, alpha=0.7, linestyle='--', marker='o', markersize=10
          , markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='green') # RGB code can be used
#ax.plot(x,y,'purple', lw=4, alpha=0.5, ls='--')

# %% [markdown]
# **Plot Range**

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,'purple', lw=2, alpha=0.7, ls='--', marker='o', markersize=10
          , markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='green')
ax.set_xlim([0,3])
ax.set_ylim([0,10])
# Out:
# (0, 10)

# %% [markdown]
# ### Special Plot Types###

# %%
plt.scatter(x,y)

# %%
#np.random.random_sample(200)
from random import sample
mydata=sample(range(1,1000),100)
plt.hist(mydata)
# Out:
# (array([12., 10.,  7., 15., 11.,  7.,  7., 11., 11.,  9.]),
#  array([  2. , 101.7, 201.4, 301.1, 400.8, 500.5, 600.2, 699.9, 799.6,
#         899.3, 999. ]),
#  <a list of 10 Patch objects>)

# %%
#data=list(np.random.normal(0, std, 100) for std in range(1,4))
data=[np.random.normal(0, std, 100) for std in range(1,4)]

# %%
plt.boxplot(data, vert=False, patch_artist=True)
plt.show()

# %% [markdown]
# ### Some References
# * http://www.matplotlib.org - The project web page for matplotlib.
# * https://github.com/matplotlib/matplotlib - The source code for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.

# %% [markdown]
# # Matplotlib Exercises
# This is exercises from Data Science Bootcamp Course
#
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# *Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?*

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y)
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.15,0.6,0.35,0.35])
ax1.plot(x,y, 'r')
ax2.plot(x,y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.show()

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.15,0.5,0.35,0.35])
ax1.plot(x,z, 'r')
ax2.plot(x,y)
ax1.set_xlabel('x')
ax1.set_ylabel('z')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim((20,22))
ax2.set_ylim((30,50))
ax2.set_title('zoom')
plt.show()

# %%
fig,ax=plt.subplots(nrows=1,ncols=2)
ax[0].plot(x,y, lw=3,ls='--')
ax[1].plot(x,z, lw=3,ls='-', color='red')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')
plt.tight_layout(2)
plt.show()

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=8) 
matplotlib.rc('ytick', labelsize=8) 
fig,ax=plt.subplots(nrows=1,ncols=2, figsize=(8,2))
ax[0].plot(x,y, lw=2,ls='-')
ax[1].plot(x,z, lw=2,ls='--', color='red')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].grid(), ax[1].grid()
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3d Figures
# *To use 3D graphics in matplotlib, we first need to create an instance of the Axes3D class*

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
fig = plt.figure()
ax3=fig.add_axes([0,0,1,1], projection='3d')
p=ax3.plot_surface(x.reshape(4,25), y.reshape(4,25), z.reshape(4,25))
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.set_zlabel('z')
ax3.set_title('My Title')
fig.colorbar(p, shrink=0.5)
plt.show()

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T


fig = plt.figure(figsize=(14,6))

# `ax` is a 3D-aware axis instance because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot with color grading and color bar
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %%
fig = plt.figure(figsize=(14,6))
ax = fig.add_axes([0,0,1,1], projection='3d')
ax.plot_wireframe(X, Y, Z, rstride=3, cstride=3)
plt.show()

# %% [markdown]
# # Seaborn
# * It is a Statistical plotting library
# * It has a very nice visualization

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig=plt.figure()
fig,ax=plt.subplots(1,2)
ax[0].boxplot(tips[tips['smoker']=='Yes']['tip'])
ax[0].set_ylim(0,12), ax[1].set_ylim(0,12)
ax[0].set_xlabel('Non Smoker'), ax[1].set_xlabel('Smoker')
ax[1].boxplot(tips[tips['smoker']=='No']['tip'])
plt.show()

# %%
tips.groupby('smoker').sum()
# Out:
#         total_bill     tip  size
# smoker
# Yes        1930.34  279.81   224
# No         2897.43  451.77   403

# %% [markdown]
# #### Set background color and style

# %%
sns.set_style("darkgrid")
sns.set_context("paper")

# %%
ax=sns.distplot(tips['total_bill'],kde=False, bins=20)

# %%
import scipy.stats as stats # pearson coeff has been removed from seaborn, so we should add it through scipy
from warnings import filterwarnings ## this is to get rid of warning message
filterwarnings('ignore')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg').annotate(stats.pearsonr) 
# default value for kind is scatter. we can use hex, reg, resid, or kde (kernal density estimation)
plt.show()

# %%
sns.pairplot(tips,hue='sex', kind='scatter') # one argument is palette such as palette='coolwarm'
# plot pairwise relationship accross the intire dataset for numerical type and hue categorical type of data

# %%
sns.rugplot(tips['total_bill']) # just like distplot it takes one data. this is ungrouped bar chart

# %%
sns.kdeplot(tips['tip'])

# %%
sns.boxplot(x='smoker', y='tip',data=tips,hue='time')

# %% [markdown]
# ### Categorical Plot with Seaborn

# %%
sns.barplot(y=tips['sex'].value_counts().values,x=tips['sex'].value_counts().index, alpha=0.7)

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=sum) # by default is mean,it can be np.std, sum, ..etc

# %%
sns.boxplot(x='day',y='total_bill', data=tips)

# %%
sns.violinplot('day', 'total_bill', data=tips)

# %%
sns.violinplot('day', 'total_bill', data=tips, hue='sex', split=True)

# %%
sns.stripplot(x='day',y='total_bill', data=tips, hue='sex')

# %%
sns.swarmplot(x='day', y='total_bill', data=tips) # this is just like a stripplot with difference that there is no overlap between points, so it is a kind of violin and strip plots combined.

# %%
# combine swarm and violin plots. This has more value for EDA rather than reporting to an executive
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, color='black')

# %% [markdown]
# #### Using a general method of Catplot (factorplot) to plot any of above standard plots

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar', estimator=sum) # former "FactorPlot"

# %% [markdown]
# ### Matrix plot (Heat Map)
# * In order for Matrix Plot to work properly, the data must be in a matrix format
# * To convert the data into a matrix, we need variables on both columns and rows
# * It can be done through a pivot table or correlation data

# %%
# %matplotlib inline
flights=sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), annot=True, cmap='coolwarm')

# %%
flights.pivot_table(index='month', columns='year', values='passengers')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
fp=flights.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(fp,cmap='magma', linecolor='white', linewidths=1)

# %% [markdown]
# ### Cluster version of HeatMap

# %%
sns.clustermap(fp,cmap='coolwarm', standard_scale=1) # there is no order here, data is split based on similarity

# %% [markdown]
# #### Grids
# * Subplot grid for plotting pairwise relationships.

# %%
iris=sns.load_dataset('iris')
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
g=sns.PairGrid (iris) # Subplot grid for plotting pairwise relationships.
g.map(plt.scatter)

# %% [markdown]
# *If I want to seperate the upper and lower diagnal of this pair plot then:*

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter, color='green')
g.map_lower(sns.kdeplot, color='red')

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_offdiag(sns.scatterplot, color='orange')

# %%
g=sns.FacetGrid(data=tips, row='smoker', col='time') # similar to subplot with difference that here we pass the column name
g.map(sns.distplot,'total_bill')
g.map(sns.scatterplot,'total_bill', 'tip')

# %% [markdown]
# ### Regression Plot

# %%
sns.lmplot('total_bill', 'tip', data=tips,hue='smoker', markers=['o','v'],
          scatter_kws={'s':100}) # through scatter_kws we pass a dictionary and 
                                 #this how we influence matplotlib from seaborn to 
                                #increase the marker size directly. S here is marker size.

# %%
sns.lmplot('total_bill', 'tip', data=tips,col='smoker', row='sex', hue='time',
        aspect=0.8, size=5) # instead of using hue for separation, we can use col and row
                                    #this is just like the facetgrid but more simple.
                                    # aspect and size are to adjust the width and height of picture

# %% [markdown]
# **Style and Color**

# %%
sns.set_context('poster', font_scale=0.8) # to change the size and font
sns.set_style('whitegrid')
sns.countplot(x='sex', data=tips)
sns.despine()  # this is to remove spines

# %%
sns.set_context('poster', font_scale=0.7)
sns.lmplot('total_bill', 'tip', data=tips, hue='sex',markers=['o','v'], scatter_kws={'s':30} ,
           palette='seismic') # also we can use ColorMap for Matplotlib for variety of color combinations

# %% [markdown]
# # Seaborn Exercises
# This is exercises from Data Science Bootcamp Course
#
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data
# We are working with the famous titanic data set

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.describe().transpose()
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
sns.set_context(font_scale=2)
sns.jointplot('fare','age', data=titanic,kind='scatter',
              joint_kws={'s':20}).annotate(stats.pearsonr)
sns.despine(top=False, right=False)

# %%
sns.reset_orig() # reset the style setting to original
sns.set_style('whitegrid')
ax=sns.distplot(titanic['fare'], bins=30,kde=False, color='red')
ax.set_xlim([0,600])
ax.set_ylim([0,500])
# Out:
# (0, 500)

# %%
sns.boxplot(y='age', x='class',data=titanic, palette='rainbow')

# %%
sns.swarmplot(y='age', x='class',data=titanic, palette='Set2')

# %%
sns.countplot(titanic['sex'], palette='husl')

# %%
sns.heatmap(titanic.corr(), cmap='coolwarm')
plt.title('Titanic Corr')
# Out:
# Text(0.5, 1, 'Titanic Corr')

# %%
sns.clustermap(titanic.corr(), cmap='coolwarm')

# %%
g=sns.FacetGrid(data=titanic, col='sex',xlim=[0,80],ylim=[0,120], size=4)
g.map(sns.distplot,'age', kde=False, color='darkblue')

# %%
g=sns.FacetGrid(data=titanic, col='sex',xlim=[0,80],ylim=[0,120], size=4)
g.map(plt.hist,'age')
